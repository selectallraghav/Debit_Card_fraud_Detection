# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/raghav/Downloads/Modified_Threat_Level_Debit_Card_Fraud_Dataa.csv")
df
# Out:
#      TransactionID AccountID  TransactionAmount      TransactionDate  \
# 0         TX000001   AC00128              14.09  2023-04-11 16:29:14
# 1         TX000002   AC00455             376.24  2023-06-27 16:44:19
# 2         TX000003   AC00019             126.29  2023-07-10 18:16:08
# 3         TX000004   AC00070             184.50  2023-05-05 16:32:11
# 4         TX000006   AC00393              92.15  2023-04-03 17:15:01
# ...            ...       ...                ...                  ...
# 1939      TX002506   AC00377             577.12  2023-01-27 17:38:07
# 1940      TX002507   AC00258              92.24  2023-04-13 17:45:33
# 1941      TX002509   AC00322             251.54  2023-03-22 17:36:48
# 1942      TX002510   AC00095              28.63  2023-08-21 17:08:50
# 1943      TX002511   AC00118             185.97  2023-02-24 16:24:46
#
#      TransactionType        Location DeviceID      IP Address MerchantID  \
# ...

# %%
df.loc[df['Fraud'] == True, 'Threat_Level'] = df.loc[df['Fraud'] == True, 'Threat Level'].apply(
    lambda x: 'Low' if x <= 1 else ('Medium' if x in [2, 3] else 'High')
)

# %%
df['Fraud'] = df['Fraud'].astype(int)

# %%
df.loc[df['Fraud'] == True]
# Out:
#      TransactionID AccountID  TransactionAmount      TransactionDate  \
# 14        TX000024   AC00453             345.84  2023-05-02 18:25:46
# 16        TX000027   AC00441             246.93  2023-04-17 16:37:01
# 21        TX000033   AC00060             396.45  2023-09-25 16:26:00
# 26        TX000039   AC00478             795.31  2023-10-12 17:07:40
# 52        TX000075   AC00265            1212.51  2023-10-04 16:36:29
# ...            ...       ...                ...                  ...
# 1841      TX002373   AC00260              95.23  2023-10-16 18:47:17
# 1863      TX002404   AC00111            1493.00  2023-06-07 17:05:41
# 1879      TX002424   AC00340             332.06  2023-06-21 16:38:54
# 1895      TX002446   AC00439             403.01  2023-09-04 17:32:35
# 1903      TX002456   AC00043             655.81  2023-05-05 16:52:44
#
#      TransactionType          Location DeviceID       IP Address MerchantID  \
# ...

# %%
df.to_csv('/Users/raghav/Downloads/Latest_Debit_card_fraud_data.csv')
